# %% [markdown]
# <a href="https://colab.research.google.com/github/jettro/colab_notebooks/blob/main/ManningLiveChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First we install the Huggingface library

# %%
# !pip install transformers

# %%
from transformers import pipeline

question_answering = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# Downloading:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/249M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
question_answering(question = "When was Pink Floyd formed?", context = "Pink Floyd was an English rock band formed in London in 1965.")
# Out:
# {'answer': '1965', 'end': 60, 'score': 0.9848853349685669, 'start': 56}
